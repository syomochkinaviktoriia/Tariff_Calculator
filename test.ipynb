# %% [markdown]
# # Тестовое задание

# %% [markdown]
# # Задание 1.
# Необходимо создать калькулятор подбора тарифного плана.
#
# На вход: тестовые данные, включающие в себя тарифы для продукта "Интернет ШПД", регионы, стоимость и технологию
# На выходе: интерфейс с выбором параметров.

# %% [markdown]
# ### Подзадача 1. Выбор технологий.
# Для создания калькулятора подбора тарифного плана были выбраны следующие технологии:
#
# * **Стек 1**: Python, Flask, PostgreSQL, PyCharm.
# * **Стек 2**: Python, Django, PostgreSQL, PyCharm.
# * **Стек 3**: Python, wxPython, PyCharm.

# %% [markdown]
# ### Предобработка данных

# %%
# импорт библиотек
import pandas as pd
import seaborn as sns

# %%
calc=pd.read_excel('selection_calculator.xlsx', index_col=0)
display(calc)
# Out:
#                                                                            Unnamed: 1  \
# Параметры на вход для подбора тарифа (цены выду...
# Линейка Скорость                                                                  NaN
# РФ                                                        Скорость_30\n (без НДС 20%)
# Астраханский филиал                                                               417
# Волгоградский филиал                                                              417
# Дагестанский филиал                                                               354
# Ингушский филиал                                                                  458
# Кабардино-Балкарский филиал                                                       458
# NaN                                                                               NaN
# Линейка Деловой (цены выдуманные):                                                NaN
# ...

# %%
calc.reset_index('Параметры на вход для подбора тарифа (цены выдуманные):', inplace=True)

# %% [markdown]
# #### Таблица 1

# %%
calc1=calc.iloc[0:7,0:25]
calc1
# Out:
#   Параметры на вход для подбора тарифа (цены выдуманные):  \
# 0                                   Линейка Скорость
# 1                                                РФ
# 2                                Астраханский филиал
# 3                               Волгоградский филиал
# 4                                Дагестанский филиал
# 5                                   Ингушский филиал
# 6                        Кабардино-Балкарский филиал
#
#                     Unnamed: 1                 Unnamed: 2  \
# 0                          NaN                        NaN
# 1  Скорость_30\n (без НДС 20%)  Скорость_30\n (с НДС 20%)
# 2                          417                      500.0
# 3                          417                      500.0
# 4                          354                      425.0
# 5                          458                      550.0
# 6                          458                      550.0
#
#                     Unnamed: 3                 Unnamed: 4  \
# ...

# %%
calc1.columns
# Out:
# Index(['Параметры на вход для подбора тарифа (цены выдуманные):', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23'],
#       dtype='object')

# %%
calc1.rename(columns={'Параметры на вход для подбора тарифа (цены выдуманные):':'branch',
                   'Unnamed: 1':'speed_30','Unnamed: 2':'speed_30_with_nds',
                    'Unnamed: 3':'speed_40','Unnamed: 4':'speed_40_with_nds',
                    'Unnamed: 5':'speed_50','Unnamed: 6':'speed_50_with_nds',
                    'Unnamed: 7':'speed_70','Unnamed: 8':'speed_70_with_nds',
                    'Unnamed: 9':'speed_100','Unnamed: 10':'speed_100_with_nds',
                    'Unnamed: 11':'speed_120','Unnamed: 12':'speed_120_with_nds',
                    'Unnamed: 13':'speed_150','Unnamed: 14':'speed_150_with_nds',
                    'Unnamed: 15':'speed_200','Unnamed: 16':'speed_200_with_nds',
                    'Unnamed: 17':'speed_250','Unnamed: 18':'speed_250_with_nds',
                    'Unnamed: 19':'speed_300','Unnamed: 20':'speed_300_with_nds',
                    'Unnamed: 21':'discount',
                    'Unnamed: 22':'role_model','Unnamed: 23':'technology'
                    },inplace=True)

# %%
calc1=calc1.drop(columns=['speed_30', 'speed_40','speed_50','speed_70','speed_100','speed_120','speed_150','speed_200','speed_250','speed_300','role_model'])

# %%
calc1=calc1.drop([0, 1]).reset_index(drop=True)

# %%
calc1
# Out:
#                         branch speed_30_with_nds speed_40_with_nds  \
# 0          Астраханский филиал             500.0             825.0
# 1         Волгоградский филиал             500.0             775.0
# 2          Дагестанский филиал             425.0             625.0
# 3             Ингушский филиал             550.0             875.0
# 4  Кабардино-Балкарский филиал             550.0             825.0
#
#   speed_50_with_nds speed_70_with_nds speed_100_with_nds speed_120_with_nds  \
# 0            1125.0            1500.0             1875.0             2250.0
# 1            1125.0            1500.0             1875.0             2250.0
# 2             875.0            1200.0             1625.0             1875.0
# 3            1250.0            1600.0             2000.0             2375.0
# 4            1125.0            1525.0             1875.0             2125.0
#
#   speed_150_with_nds speed_200_with_nds speed_250_with_nds speed_300_with_nds  \
# ...

# %%
calc1=calc1.replace({'10%, 20%, 30%': '10, 20, 30'})

# %%
calc1['name_of_tariff']='Линейка скорость'

# %%
calc1.head(10)
# Out:
#                         branch  speed_30_with_nds  speed_40_with_nds  \
# 0          Астраханский филиал              500.0              825.0
# 1         Волгоградский филиал              500.0              775.0
# 2          Дагестанский филиал              425.0              625.0
# 3             Ингушский филиал              550.0              875.0
# 4  Кабардино-Балкарский филиал              550.0              825.0
#
#    speed_50_with_nds  speed_70_with_nds  speed_100_with_nds  \
# 0             1125.0             1500.0              1875.0
# 1             1125.0             1500.0              1875.0
# 2              875.0             1200.0              1625.0
# 3             1250.0             1600.0              2000.0
# 4             1125.0             1525.0              1875.0
#
#    speed_120_with_nds  speed_150_with_nds  speed_200_with_nds  \
# 0              2250.0              2625.0              3000.0
# ...

# %%
d1 = {'branch': [
            calc1['branch'][0], calc1['branch'][1],
            calc1['branch'][2], calc1['branch'][3],
            calc1['branch'][4],
            calc1['branch'][0], calc1['branch'][1],
            calc1['branch'][2], calc1['branch'][3],
            calc1['branch'][4],
            calc1['branch'][0], calc1['branch'][1],
            calc1['branch'][2], calc1['branch'][3],
            calc1['branch'][4],
            calc1['branch'][0], calc1['branch'][1],
            calc1['branch'][2], calc1['branch'][3],
            calc1['branch'][4],
            calc1['branch'][0], calc1['branch'][1],
            calc1['branch'][2], calc1['branch'][3],
            calc1['branch'][4],
            calc1['branch'][0], calc1['branch'][1],
            calc1['branch'][2], calc1['branch'][3],
            calc1['branch'][4],
            calc1['branch'][0], calc1['branch'][1],
            calc1['branch'][2], calc1['branch'][3],
            calc1['branch'][4],
            calc1['branch'][0], calc1['branch'][1],
            calc1['branch'][2], calc1['branch'][3],
            calc1['branch'][4],
            calc1['branch'][0], calc1['branch'][1],
            calc1['branch'][2], calc1['branch'][3],
            calc1['branch'][4],
            calc1['branch'][0], calc1['branch'][1],
            calc1['branch'][2], calc1['branch'][3],
            calc1['branch'][4]
  
            ], 
     
     'name_of_tariff':[calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],calc1['name_of_tariff'][0],
                       calc1['name_of_tariff'][0],calc1['name_of_tariff'][0]],
     
     'speed': [30, 30, 30, 30, 30, 40, 40, 40, 40, 40, 50, 50, 50, 50, 50, 70, 70, 70, 70, 70, 100, 100, 100, 100, 100, 120, 120, 120, 120, 120, 150, 150, 150, 150, 150, 200, 200, 200, 200, 200, 250, 250, 250, 250, 250, 300, 300, 300, 300,300],

     'price': [
                        calc1['speed_30_with_nds'][0], calc1['speed_30_with_nds'][1], calc1['speed_30_with_nds'][2], calc1['speed_30_with_nds'][3], calc1['speed_30_with_nds'][4],
                        calc1['speed_40_with_nds'][0], calc1['speed_40_with_nds'][1], calc1['speed_40_with_nds'][2], calc1['speed_40_with_nds'][3], calc1['speed_40_with_nds'][4],
                        calc1['speed_50_with_nds'][0], calc1['speed_50_with_nds'][1], calc1['speed_50_with_nds'][2], calc1['speed_50_with_nds'][3], calc1['speed_50_with_nds'][4],
                        calc1['speed_70_with_nds'][0], calc1['speed_70_with_nds'][1], calc1['speed_70_with_nds'][2], calc1['speed_70_with_nds'][3], calc1['speed_70_with_nds'][4],
                        calc1['speed_100_with_nds'][0], calc1['speed_100_with_nds'][1], calc1['speed_100_with_nds'][2], calc1['speed_100_with_nds'][3], calc1['speed_100_with_nds'][4],
                        calc1['speed_120_with_nds'][0], calc1['speed_120_with_nds'][1], calc1['speed_120_with_nds'][2], calc1['speed_120_with_nds'][3], calc1['speed_120_with_nds'][4],
                        calc1['speed_150_with_nds'][0], calc1['speed_150_with_nds'][1], calc1['speed_150_with_nds'][2], calc1['speed_150_with_nds'][3], calc1['speed_150_with_nds'][4],
                        calc1['speed_200_with_nds'][0], calc1['speed_200_with_nds'][1], calc1['speed_200_with_nds'][2], calc1['speed_200_with_nds'][3], calc1['speed_200_with_nds'][4],
                        calc1['speed_250_with_nds'][0], calc1['speed_250_with_nds'][1], calc1['speed_250_with_nds'][2], calc1['speed_250_with_nds'][3], calc1['speed_250_with_nds'][4],
                        calc1['speed_300_with_nds'][0], calc1['speed_300_with_nds'][1], calc1['speed_300_with_nds'][2], calc1['speed_300_with_nds'][3], calc1['speed_300_with_nds'][4]
                        

                        ],
     
     'discount':[
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0],calc1['discount'][0],
                  calc1['discount'][0],calc1['discount'][0]
                  
                 
     ],

     

     'technology': [
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0],calc1['technology'][0],
                  calc1['technology'][0],calc1['technology'][0]
                  
                  ],
     
    


   }


calc1_1 = pd.DataFrame(data=d1)

# %%
calc1_1.head(10)
# Out:
#                         branch    name_of_tariff  speed  price    discount  \
# 0          Астраханский филиал  Линейка скорость     30  500.0  10, 20, 30
# 1         Волгоградский филиал  Линейка скорость     30  500.0  10, 20, 30
# 2          Дагестанский филиал  Линейка скорость     30  425.0  10, 20, 30
# 3             Ингушский филиал  Линейка скорость     30  550.0  10, 20, 30
# 4  Кабардино-Балкарский филиал  Линейка скорость     30  550.0  10, 20, 30
# 5          Астраханский филиал  Линейка скорость     40  825.0  10, 20, 30
# 6         Волгоградский филиал  Линейка скорость     40  775.0  10, 20, 30
# 7          Дагестанский филиал  Линейка скорость     40  625.0  10, 20, 30
# 8             Ингушский филиал  Линейка скорость     40  875.0  10, 20, 30
# 9  Кабардино-Балкарский филиал  Линейка скорость     40  825.0  10, 20, 30
#
#                      technology
# 0  оптика  - ETTH/Ethernet/xPON
# 1  оптика  - ETTH/Ethernet/xPON
# 2  оптика  - ETTH/Ethernet/xPON
# ...

# %% [markdown]
# #### Таблица 2

# %%
calc2=calc.iloc[10:15,0:12]
calc2
# Out:
#    Параметры на вход для подбора тарифа (цены выдуманные): Unnamed: 1  \
# 10                                Астраханский филиал          583.33
# 11                               Волгоградский филиал          583.33
# 12                                Дагестанский филиал          583.33
# 13                                   Ингушский филиал          791.67
# 14                        Кабардино-Балкарский филиал          791.67
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 10      700.0        625      750.0     666.67      800.0     708.33
# 11      700.0        625      750.0     666.67      800.0     708.33
# 12      700.0        625      750.0     666.67      800.0     708.33
# 13      950.0     916.67     1100.0       1000     1200.0    1083.33
# 14      950.0     958.33     1150.0       1125     1350.0       1250
#
#    Unnamed: 8     Unnamed: 9  \
# 10      850.0  10%, 20%, 30%
# 11      850.0  10%, 20%, 30%
# 12      850.0  10%, 20%, 30%
# ...

# %%
calc2.columns
# Out:
# Index(['Параметры на вход для подбора тарифа (цены выдуманные):', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %%
calc2.rename(columns={'Параметры на вход для подбора тарифа (цены выдуманные):':'branch',
                   'Unnamed: 1':'speed_4','Unnamed: 2':'speed_4_with_nds',
                    'Unnamed: 3':'speed_6','Unnamed: 4':'speed_6_with_nds',
                    'Unnamed: 5':'speed_8','Unnamed: 6':'speed_8_with_nds',
                    'Unnamed: 7':'speed_10','Unnamed: 8':'speed_10_with_nds',
                    'Unnamed: 9':'discount','Unnamed: 10':'role_model',
                    'Unnamed: 11':'technology'},inplace=True)

# %%
calc2=calc2.replace({'10%, 20%, 30%': '10, 20, 30'})

# %%
calc2=calc2.drop(columns=['speed_4', 'speed_6','speed_8','speed_10','role_model']).reset_index(drop=True)

# %%
calc2['name_of_tariff']='Линейка Деловой'

# %%
calc2
# Out:
#                         branch  speed_4_with_nds  speed_6_with_nds  \
# 0          Астраханский филиал             700.0             750.0
# 1         Волгоградский филиал             700.0             750.0
# 2          Дагестанский филиал             700.0             750.0
# 3             Ингушский филиал             950.0            1100.0
# 4  Кабардино-Балкарский филиал             950.0            1150.0
#
#    speed_8_with_nds  speed_10_with_nds    discount   technology  \
# 0             800.0              850.0  10, 20, 30  медь - xDSL
# 1             800.0              850.0  10, 20, 30  медь - xDSL
# 2             800.0              850.0  10, 20, 30  медь - xDSL
# 3            1200.0             1300.0  10, 20, 30  медь - xDSL
# 4            1350.0             1500.0  10, 20, 30  медь - xDSL
#
#     name_of_tariff
# 0  Линейка Деловой
# 1  Линейка Деловой
# 2  Линейка Деловой
# 3  Линейка Деловой
# 4  Линейка Деловой

# %%
d2 = {'branch': [
            calc2['branch'][0], calc2['branch'][1],
            calc2['branch'][2], calc2['branch'][3],
            calc2['branch'][4],
            calc2['branch'][0], calc2['branch'][1],
            calc2['branch'][2], calc2['branch'][3],
            calc2['branch'][4],
            calc2['branch'][0], calc2['branch'][1],
            calc2['branch'][2], calc2['branch'][3],
            calc2['branch'][4],
            calc2['branch'][0], calc2['branch'][1],
            calc2['branch'][2], calc2['branch'][3],
            calc2['branch'][4]
  
            ], 
     
     'name_of_tariff':[calc2['name_of_tariff'][0],calc2['name_of_tariff'][0],calc2['name_of_tariff'][0],
                       calc2['name_of_tariff'][0],calc2['name_of_tariff'][0],calc2['name_of_tariff'][0],
                       calc2['name_of_tariff'][0],calc2['name_of_tariff'][0],calc2['name_of_tariff'][0],
                       calc2['name_of_tariff'][0],calc2['name_of_tariff'][0],calc2['name_of_tariff'][0],
                       calc2['name_of_tariff'][0],calc2['name_of_tariff'][0],calc2['name_of_tariff'][0],
                       calc2['name_of_tariff'][0],calc2['name_of_tariff'][0],calc2['name_of_tariff'][0],
                       calc2['name_of_tariff'][0],calc2['name_of_tariff'][0]],
     
     'speed': [4, 4, 4, 4, 4, 6, 6, 6, 6, 6, 8, 8, 8, 8, 8, 10, 10, 10, 10, 10],

     'price': [
                        calc2['speed_4_with_nds'][0], calc2['speed_4_with_nds'][1], calc2['speed_4_with_nds'][2], calc2['speed_4_with_nds'][3], calc2['speed_4_with_nds'][4],
                        calc2['speed_6_with_nds'][0], calc2['speed_6_with_nds'][1], calc2['speed_6_with_nds'][2], calc2['speed_6_with_nds'][3], calc2['speed_6_with_nds'][4],
                        calc2['speed_8_with_nds'][0], calc2['speed_8_with_nds'][1], calc2['speed_8_with_nds'][2], calc2['speed_8_with_nds'][3], calc2['speed_8_with_nds'][4],
                        calc2['speed_10_with_nds'][0], calc2['speed_10_with_nds'][1], calc2['speed_10_with_nds'][2], calc2['speed_10_with_nds'][3], calc2['speed_10_with_nds'][4]

                        ],
     
     'discount':[
                  calc2['discount'][0],calc2['discount'][0],calc2['discount'][0],
                  calc2['discount'][0],calc2['discount'][0],calc2['discount'][0],
                  calc2['discount'][0],calc2['discount'][0],calc2['discount'][0],
                  calc2['discount'][0],calc2['discount'][0],calc2['discount'][0],
                  calc2['discount'][0],calc2['discount'][0],calc2['discount'][0],
                  calc2['discount'][0],calc2['discount'][0],calc2['discount'][0],
                  calc2['discount'][0],calc2['discount'][0]
                  
                 
     ],

     

     'technology': [
                  calc2['technology'][0],calc2['technology'][0],calc2['technology'][0],
                  calc2['technology'][0],calc2['technology'][0],calc2['technology'][0],
                  calc2['technology'][0],calc2['technology'][0],calc2['technology'][0],
                  calc2['technology'][0],calc2['technology'][0],calc2['technology'][0],
                  calc2['technology'][0],calc2['technology'][0],calc2['technology'][0],
                  calc2['technology'][0],calc2['technology'][0],calc2['technology'][0],
                  calc2['technology'][0],calc2['technology'][0]

                  
                  ],
     
    


   }


calc2_1 = pd.DataFrame(data=d2)

# %%
calc2_1
# Out:
#                          branch   name_of_tariff  speed   price    discount  \
# 0           Астраханский филиал  Линейка Деловой      4   700.0  10, 20, 30
# 1          Волгоградский филиал  Линейка Деловой      4   700.0  10, 20, 30
# 2           Дагестанский филиал  Линейка Деловой      4   700.0  10, 20, 30
# 3              Ингушский филиал  Линейка Деловой      4   950.0  10, 20, 30
# 4   Кабардино-Балкарский филиал  Линейка Деловой      4   950.0  10, 20, 30
# 5           Астраханский филиал  Линейка Деловой      6   750.0  10, 20, 30
# 6          Волгоградский филиал  Линейка Деловой      6   750.0  10, 20, 30
# 7           Дагестанский филиал  Линейка Деловой      6   750.0  10, 20, 30
# 8              Ингушский филиал  Линейка Деловой      6  1100.0  10, 20, 30
# 9   Кабардино-Балкарский филиал  Линейка Деловой      6  1150.0  10, 20, 30
# 10          Астраханский филиал  Линейка Деловой      8   800.0  10, 20, 30
# ...

# %% [markdown]
# #### Таблица 3

# %%
calc3=calc.iloc[18:23,0:7].reset_index(drop=True)
calc3
# Out:
#   Параметры на вход для подбора тарифа (цены выдуманные): Unnamed: 1  \
# 0                                Астраханский филиал           687.5
# 1                               Волгоградский филиал           687.5
# 2                                Дагестанский филиал          479.17
# 3                                   Ингушский филиал          791.67
# 4                        Кабардино-Балкарский филиал           687.5
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4    Unnamed: 5                    Unnamed: 6
# 0      825.0     1312.5     1575.0  не действуют  оптика  - ETTH/Ethernet/xPON
# 1      825.0     1312.5     1575.0  не действуют  оптика  - ETTH/Ethernet/xPON
# 2      575.0    1104.17     1325.0  не действуют  оптика  - ETTH/Ethernet/xPON
# 3      950.0    1416.67     1700.0  не действуют  оптика  - ETTH/Ethernet/xPON
# 4      825.0     1312.5     1575.0  не действуют  оптика  - ETTH/Ethernet/xPON

# %%
calc3.columns
# Out:
# Index(['Параметры на вход для подбора тарифа (цены выдуманные):', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
calc3.rename(columns={'Параметры на вход для подбора тарифа (цены выдуманные):':'branch',
                   'Unnamed: 1':'speed_ojn_50','Unnamed: 2':'speed_ojn_50_with_nds',
                    'Unnamed: 3':'speed_ojn_100','Unnamed: 4':'speed_ojn_100_with_nds',
                    'Unnamed: 5':'discount','Unnamed: 6':'technology'
                    },inplace=True)

# %%
calc3['discount']=0
calc3
# Out:
#                         branch speed_ojn_50 speed_ojn_50_with_nds  \
# 0          Астраханский филиал        687.5                 825.0
# 1         Волгоградский филиал        687.5                 825.0
# 2          Дагестанский филиал       479.17                 575.0
# 3             Ингушский филиал       791.67                 950.0
# 4  Кабардино-Балкарский филиал        687.5                 825.0
#
#   speed_ojn_100 speed_ojn_100_with_nds  discount                    technology
# 0        1312.5                 1575.0         0  оптика  - ETTH/Ethernet/xPON
# 1        1312.5                 1575.0         0  оптика  - ETTH/Ethernet/xPON
# 2       1104.17                 1325.0         0  оптика  - ETTH/Ethernet/xPON
# 3       1416.67                 1700.0         0  оптика  - ETTH/Ethernet/xPON
# 4        1312.5                 1575.0         0  оптика  - ETTH/Ethernet/xPON

# %%
calc3['name_of_tariff']='Линейка ОЖН'

# %%
calc3=calc3.drop(columns=['speed_ojn_50', 'speed_ojn_100']).reset_index(drop=True)

# %%
calc3
# Out:
#                         branch speed_ojn_50_with_nds speed_ojn_100_with_nds  \
# 0          Астраханский филиал                 825.0                 1575.0
# 1         Волгоградский филиал                 825.0                 1575.0
# 2          Дагестанский филиал                 575.0                 1325.0
# 3             Ингушский филиал                 950.0                 1700.0
# 4  Кабардино-Балкарский филиал                 825.0                 1575.0
#
#    discount                    technology name_of_tariff
# 0         0  оптика  - ETTH/Ethernet/xPON    Линейка ОЖН
# 1         0  оптика  - ETTH/Ethernet/xPON    Линейка ОЖН
# 2         0  оптика  - ETTH/Ethernet/xPON    Линейка ОЖН
# 3         0  оптика  - ETTH/Ethernet/xPON    Линейка ОЖН
# 4         0  оптика  - ETTH/Ethernet/xPON    Линейка ОЖН

# %%
d3 = {'branch': [
            calc3['branch'][0], calc3['branch'][1],
            calc3['branch'][2], calc3['branch'][3],
            calc3['branch'][4],
            calc3['branch'][0], calc3['branch'][1],
            calc3['branch'][2], calc3['branch'][3],
            calc3['branch'][4]
  
            ], 
     
     'name_of_tariff':[calc3['name_of_tariff'][0],calc3['name_of_tariff'][0],calc3['name_of_tariff'][0],
                       calc3['name_of_tariff'][0],calc3['name_of_tariff'][0],calc3['name_of_tariff'][0],
                       calc3['name_of_tariff'][0],calc3['name_of_tariff'][0],calc3['name_of_tariff'][0],
                       calc3['name_of_tariff'][0]],
     
     'speed': [50, 50, 50, 50, 50, 100, 100, 100, 100, 100],

     'price': [
                        calc3['speed_ojn_50_with_nds'][0], calc3['speed_ojn_50_with_nds'][1], calc3['speed_ojn_50_with_nds'][2], calc3['speed_ojn_50_with_nds'][3], calc3['speed_ojn_50_with_nds'][4],
                        calc3['speed_ojn_100_with_nds'][0], calc3['speed_ojn_100_with_nds'][1], calc3['speed_ojn_100_with_nds'][2], calc3['speed_ojn_100_with_nds'][3], calc3['speed_ojn_100_with_nds'][4]


                        ],
     
     'discount':[
                  calc3['discount'][0],calc3['discount'][0],calc3['discount'][0],
                  calc3['discount'][0],calc3['discount'][0],calc3['discount'][0],
                  calc3['discount'][0],calc3['discount'][0],calc3['discount'][0],
                  calc3['discount'][0]
                  
                 
     ],

     

     'technology': [
                  calc3['technology'][0],calc3['technology'][0],calc3['technology'][0],
                  calc3['technology'][0],calc3['technology'][0],calc3['technology'][0],
                  calc3['technology'][0],calc3['technology'][0],calc3['technology'][0],
                  calc3['technology'][0]
                  
                  ],
     
    


   }


calc3_1 = pd.DataFrame(data=d3)

# %%
calc3_1
# Out:
#                         branch name_of_tariff  speed   price  discount  \
# 0          Астраханский филиал    Линейка ОЖН     50   825.0         0
# 1         Волгоградский филиал    Линейка ОЖН     50   825.0         0
# 2          Дагестанский филиал    Линейка ОЖН     50   575.0         0
# 3             Ингушский филиал    Линейка ОЖН     50   950.0         0
# 4  Кабардино-Балкарский филиал    Линейка ОЖН     50   825.0         0
# 5          Астраханский филиал    Линейка ОЖН    100  1575.0         0
# 6         Волгоградский филиал    Линейка ОЖН    100  1575.0         0
# 7          Дагестанский филиал    Линейка ОЖН    100  1325.0         0
# 8             Ингушский филиал    Линейка ОЖН    100  1700.0         0
# 9  Кабардино-Балкарский филиал    Линейка ОЖН    100  1575.0         0
#
#                      technology
# 0  оптика  - ETTH/Ethernet/xPON
# 1  оптика  - ETTH/Ethernet/xPON
# 2  оптика  - ETTH/Ethernet/xPON
# 3  оптика  - ETTH/Ethernet/xPON
# ...

# %% [markdown]
# #### Соединение таблиц

# %%
calc_general =pd.concat([calc1_1,calc2_1, calc3_1],axis=0).reset_index(drop=True)
display(calc_general)
# Out:
#                          branch    name_of_tariff  speed   price    discount  \
# 0           Астраханский филиал  Линейка скорость     30   500.0  10, 20, 30
# 1          Волгоградский филиал  Линейка скорость     30   500.0  10, 20, 30
# 2           Дагестанский филиал  Линейка скорость     30   425.0  10, 20, 30
# 3              Ингушский филиал  Линейка скорость     30   550.0  10, 20, 30
# 4   Кабардино-Балкарский филиал  Линейка скорость     30   550.0  10, 20, 30
# ..                          ...               ...    ...     ...         ...
# 75          Астраханский филиал       Линейка ОЖН    100  1575.0           0
# 76         Волгоградский филиал       Линейка ОЖН    100  1575.0           0
# 77          Дагестанский филиал       Линейка ОЖН    100  1325.0           0
# 78             Ингушский филиал       Линейка ОЖН    100  1700.0           0
# 79  Кабардино-Балкарский филиал       Линейка ОЖН    100  1575.0           0
#
#                       technology
# ...

# %%
calc_general.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   branch          80 non-null     object
#  1   name_of_tariff  80 non-null     object
#  2   speed           80 non-null     int64
#  3   price           80 non-null     float64
#  4   discount        80 non-null     object
#  5   technology      80 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 3.9+ KB

# %%
# запись в csv файл
with open('general.csv','w') as csv_file:
  calc_general.to_csv(path_or_buf=csv_file)

# %% [markdown]
# ### Калькулятор подбора
# Для того, чтобы использовать данное приложение на локальном компьютере необходимо установить python3 и запустить приложение в консоли с помощью команды *pythonw main.py* (*main.py*-имя приложения).

# %% [markdown]
# На картинках представлена интерпретация приложения на операционной системе MacOs Monterey 12.4.

# %% [markdown]
# В контекстном меню выбирается таблица в формате ".csv".

# %% [markdown]
# ![Снимок экрана 2022-06-17 в 08.34.54.png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана 2022-06-17 в 08.35.06.png](data:image/png;base64,...)

# %% [markdown]
# В первом поле пользователь выбирает филиал.

# %% [markdown]
# ![Снимок экрана 2022-06-17 в 08.35.36.png](data:image/png;base64,...)

# %% [markdown]
# Во втором поле пользователь выбирает технологию.

# %% [markdown]
# ![Снимок экрана 2022-06-17 в 08.35.48.png](data:image/png;base64,...)

# %% [markdown]
# В третьем поле - скорость.

# %% [markdown]
# ![Снимок экрана 2022-06-17 в 08.36.02.png](data:image/png;base64,...)

# %% [markdown]
# Результат - отображение таблицы возможных вариантов по данным фильтрам.

# %% [markdown]
# ![Снимок экрана 2022-06-17 в 08.36.49.png](data:image/png;base64,...)

# %% [markdown]
# Так же важно отметить наличие параметра "для любого", с помощью которого пользователь может рассмотреть всевозможные варианты.

# %% [markdown]
# ![Снимок экрана 2022-06-17 в 08.38.13.png](data:image/png;base64,...)

# %% [markdown]
# Приложение было написано с помощью следующих технологий: Python, библиотеки-обертки для реализации графического интерфеса wxPython, pandas в среде разработки PyCharm.
#
# Данное решение является оптимальным для автоматизации внутренних бизнес-процессов, так как не требует использования BI-систем.
#
# Приложение "Калькулятор подбора" нуждается в доработке таблиц и добавлении фильтра "стоимость".
